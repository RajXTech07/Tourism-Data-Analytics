# %%
import pandas as pd
reviews = pd.read_csv("../data/raw/processed/clean_reviews.csv")
print(reviews.columns)
# Out:
# Index(['City', 'Place', 'Review', 'Rating', 'Name', 'Date', 'Raw_Review'], dtype='str')
